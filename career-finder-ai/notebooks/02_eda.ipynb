# %% [markdown]
# # 02 – Exploratory Data Analysis (EDA)
#
# Visualise distributions of cities, work modes, program types, and majors.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid')
PROCESSED_DIR = Path('../data/processed')

# %%
opps_path = PROCESSED_DIR / 'opportunities_clean.csv'
if opps_path.exists():
    df = pd.read_csv(opps_path)
    print(f'Opportunities: {len(df)} rows')
    display(df.head())
else:
    print('Run clean_data.py first.')

# %%
if 'df' in dir():
    fig, axes = plt.subplots(1, 3, figsize=(15, 4))
    for ax, col in zip(axes, ['city', 'work_mode', 'program_type']):
        if col in df.columns:
            df[col].value_counts().plot(kind='bar', ax=ax, title=col)
            ax.set_xlabel('')
    plt.tight_layout()
    plt.savefig('../reports/figures/eda_distributions.png', dpi=150)
    plt.show()
